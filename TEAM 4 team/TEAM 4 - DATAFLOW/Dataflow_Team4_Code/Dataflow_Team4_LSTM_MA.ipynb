# %% [markdown]
# # A. Nhập dữ liệu

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import seaborn as sns
import math # thư viện math

#LSTM
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra
from tensorflow.keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_percentage_error #đo MAPE
from sklearn.metrics import mean_squared_error #MSE để tính RMSE

import warnings
warnings.filterwarnings("ignore")

# %%
#tạo quyền truy cập với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#đọc dữ liệu từ file csv
df_train = pd.read_csv('/content/drive/MyDrive/2025/data_goc/train.csv',parse_dates=['Date'])
df_test = pd.read_csv('/content/drive/MyDrive/2025/data_goc/test.csv',parse_dates=['Date'])

# %%
#kích thước của tập train
print(f"Tập train bao gồm {df_train.shape[0]} dòng và {df_train.shape[1]} cột.")
#kích thước của tập test
print(f"Tập test bao gồm {df_test.shape[0]} dòng và {df_test.shape[1]} cột.")
# Out:
# Tập train bao gồm 901561 dòng và 6 cột.
# Tập test bao gồm 74682 dòng và 6 cột.

# %% [markdown]
# # B. Tiền xử lý dữ liệu

# %%
# Gộp data có cùng ngày lại và tạo 1 data bao gồm 3 cột date, units và revenue
train_1= df_train.groupby('Date')[['Units','Revenue']].sum().reset_index()
test_1= df_test.groupby('Date')[['Units','Revenue']].sum().reset_index()

# %%
# Xử lý dữ liệu Tập Train
# Kiểm tra dữ liệu của cột 'Date'
train_1['Date'] = pd.to_datetime(train_1['Date'])
full_date_range_train = pd.date_range(start=train_1['Date'].min(), end=train_1['Date'].max(), freq='D')
missing_date_train = full_date_range_train.difference(train_1['Date'])
print(missing_date_train)

# Điền dữ liệu bị thiếu của các cột bằng dữ liệu của ngày hôm trước
train_1 = train_1.set_index('Date').reindex(full_date_range_train).reset_index()
train_1.rename(columns={'index': 'Date'}, inplace=True)
train_1.fillna(method='ffill', inplace=True)
# Out:
# DatetimeIndex(['2010-07-30', '2010-08-13', '2010-08-27', '2010-09-30',
#                '2010-10-13', '2010-11-09', '2010-11-16', '2010-11-30',
#                '2010-12-01', '2010-12-25',
#                ...
#                '2019-05-02', '2019-07-02', '2019-10-01', '2019-12-01',
#                '2020-03-01', '2020-03-02', '2020-05-02', '2020-07-02',
#                '2020-09-30', '2020-11-30'],
#               dtype='datetime64[ns]', length=116, freq=None)

# %%
# Xử lý dữ liệu Tập Test
# Kiểm tra dữ liệu của cột 'Date'
test_1['Date'] = pd.to_datetime(test_1['Date'])
full_date_range_test = pd.date_range(start=test_1['Date'].min(), end=test_1['Date'].max(), freq='D')
missing_date_test = full_date_range_test.difference(train_1['Date'])
print(missing_date_test)

# Điền dữ liệu bị thiếu của các cột bằng dữ liệu của ngày hôm trước
test_1 = test_1.set_index('Date').reindex(full_date_range_test).reset_index()
test_1.rename(columns={'index': 'Date'}, inplace=True)
test_1.fillna(method='ffill', inplace=True)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2022-06-22', '2022-06-23', '2022-06-24', '2022-06-25',
#                '2022-06-26', '2022-06-27', '2022-06-28', '2022-06-29',
#                '2022-06-30', '2022-07-01'],
#               dtype='datetime64[ns]', length=547, freq='D')

# %%
# Gom data có cùng ngày lại và tạo 1 data chỉ có 2 cột date và Units
train_units= train_1.groupby('Date')['Units'].sum().reset_index()
test_units= test_1.groupby('Date')['Units'].sum().reset_index()

# Gom data có cùng ngày lại và tạo 1 data chỉ có 2 cột date và revenue
train_revenue= train_1.groupby('Date')['Revenue'].sum().reset_index()
test_revenue= test_1.groupby('Date')['Revenue'].sum().reset_index()

# %%
# set index
train_units = train_units.set_index('Date')
test_units = test_units.set_index('Date')

train_revenue = train_revenue.set_index('Date')
test_revenue = test_revenue.set_index('Date')

# %%
# Kích thước của tập train revenue
print(f"Tập train bao gồm {train_revenue.shape[0]} dòng và {train_revenue.shape[1]} cột.")
# Kích thước của tập test revenue
print(f"Tập test bao gồm {test_revenue.shape[0]} dòng và {test_revenue.shape[1]} cột.")
# Out:
# Tập train bao gồm 3834 dòng và 1 cột.
# Tập test bao gồm 547 dòng và 1 cột.

# %% [markdown]
# # C. Feature Engineering

# %% [markdown]
# ## Áp dụng Trung Bình Trượt (Moving Average)

# %% [markdown]
# ### Revenue

# %%
def apply_moving_averages(df):
    df["revenue_MA_7"] = df["Revenue"].rolling(window=7).mean()
    df["revenue_MA_15"] = df["Revenue"].rolling(window=15).mean()
    df["revenue_MA_30"] = df["Revenue"].rolling(window=30).mean()
    df["revenue_MA_60"] = df["Revenue"].rolling(window=60).mean()
    df.fillna(method='bfill',inplace=True)
    return df

train_revenue = apply_moving_averages(train_revenue)
test_revenue = apply_moving_averages(test_revenue)

# %% [markdown]
# ### Unit Sold

# %%
def apply_moving_averages_2(df):
    df["unit_MA_7"] = df["Units"].rolling(window=7).mean()
    df["unit_MA_15"] = df["Units"].rolling(window=15).mean()
    df["unit_MA_30"] = df["Units"].rolling(window=30).mean()
    df["unit_MA_60"] = df["Units"].rolling(window=60).mean()
    df.fillna(method='bfill',inplace=True)
    return df

train_units = apply_moving_averages_2(train_units)
test_units = apply_moving_averages_2(test_units)

# %% [markdown]
# # D. Xây dựng mô hình LSTM

# %% [markdown]
# ## I. Revenue

# %%
# Chuẩn hóa dữ liệu (Scaling từ 0 đến 1)
scaler = MinMaxScaler(feature_range=(0, 1))
sc_train = scaler.fit_transform(train_revenue[['revenue_MA_7','revenue_MA_15','revenue_MA_30','revenue_MA_60']])
sc_test = scaler.transform(test_revenue[['revenue_MA_7','revenue_MA_15','revenue_MA_30','revenue_MA_60']])

# %%
# Chuyển đổi dữ liệu thành dạng có thể sử dụng cho LSTM (sequence data)
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), :])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Tạo dữ liệu đầu vào cho mô hình LSTM
time_step = 45  # Sử dụng 45 ngày trước đó để dự đoán ngày tiếp theo
X_train, y_train = create_dataset(sc_train, time_step)
X_test, y_test = create_dataset(sc_test, time_step)

# Reshape dữ liệu cho LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],  X_test.shape[2])

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Sử dụng ModelCheckpoint để lưu mô hình tốt nhất
save_model = "/content/drive/MyDrive/2025/revenue_model.keras"
best_model = ModelCheckpoint(save_model, monitor='val_loss', verbose=2, save_best_only=True, mode='auto')
model.fit(X_train, y_train, epochs=80, batch_size=32, verbose=2, validation_data=(X_test, y_test), callbacks=[best_model])

# Dự đoán doanh thu cho tập test
predictions = model.predict(X_test)

# Chuyển đổi dự đoán trở lại giá trị gốc (denormalization)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], 3))), axis=1))[:, 0]
y_test_actual = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 3))), axis=1))[:, 0]
# Out:
# Epoch 1/80
#
# Epoch 1: val_loss improved from inf to 0.00456, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 16s - 136ms/step - loss: 0.0100 - val_loss: 0.0046
# Epoch 2/80
#
# Epoch 2: val_loss improved from 0.00456 to 0.00204, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 19s - 161ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 3/80
#
# Epoch 3: val_loss improved from 0.00204 to 0.00170, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 91ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 4/80
#
# Epoch 4: val_loss improved from 0.00170 to 0.00159, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 19s - 162ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 5/80
#
# Epoch 5: val_loss improved from 0.00159 to 0.00138, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 12s - 98ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 6/80
#
# Epoch 6: val_loss improved from 0.00138 to 0.00132, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 20s - 164ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 7/80
#
# Epoch 7: val_loss improved from 0.00132 to 0.00116, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 10s - 82ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 8/80
#
# Epoch 8: val_loss improved from 0.00116 to 0.00111, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 12s - 98ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 9/80
#
# Epoch 9: val_loss did not improve from 0.00111
# 119/119 - 20s - 167ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 10/80
#
# Epoch 10: val_loss improved from 0.00111 to 0.00100, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 21s - 173ms/step - loss: 0.0015 - val_loss: 9.9677e-04
# Epoch 11/80
#
# Epoch 11: val_loss did not improve from 0.00100
# 119/119 - 20s - 170ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 12/80
#
# Epoch 12: val_loss improved from 0.00100 to 0.00098, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 21s - 175ms/step - loss: 0.0016 - val_loss: 9.7922e-04
# Epoch 13/80
#
# Epoch 13: val_loss improved from 0.00098 to 0.00095, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 21s - 177ms/step - loss: 0.0015 - val_loss: 9.5386e-04
# Epoch 14/80
#
# Epoch 14: val_loss did not improve from 0.00095
# 119/119 - 20s - 165ms/step - loss: 0.0015 - val_loss: 9.9075e-04
# Epoch 15/80
#
# Epoch 15: val_loss improved from 0.00095 to 0.00090, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 91ms/step - loss: 0.0014 - val_loss: 9.0414e-04
# Epoch 16/80
#
# Epoch 16: val_loss did not improve from 0.00090
# 119/119 - 18s - 153ms/step - loss: 0.0014 - val_loss: 9.2704e-04
# Epoch 17/80
#
# Epoch 17: val_loss did not improve from 0.00090
# 119/119 - 12s - 97ms/step - loss: 0.0014 - val_loss: 9.1896e-04
# Epoch 18/80
#
# Epoch 18: val_loss did not improve from 0.00090
# 119/119 - 11s - 92ms/step - loss: 0.0014 - val_loss: 9.8141e-04
# Epoch 19/80
#
# Epoch 19: val_loss did not improve from 0.00090
# 119/119 - 18s - 154ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 20/80
#
# Epoch 20: val_loss improved from 0.00090 to 0.00087, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 94ms/step - loss: 0.0014 - val_loss: 8.7125e-04
# Epoch 21/80
#
# Epoch 21: val_loss did not improve from 0.00087
# 119/119 - 12s - 97ms/step - loss: 0.0013 - val_loss: 9.3693e-04
# Epoch 22/80
#
# Epoch 22: val_loss did not improve from 0.00087
# 119/119 - 19s - 163ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 23/80
#
# Epoch 23: val_loss did not improve from 0.00087
# 119/119 - 10s - 83ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 24/80
#
# Epoch 24: val_loss improved from 0.00087 to 0.00079, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 89ms/step - loss: 0.0013 - val_loss: 7.8956e-04
# Epoch 25/80
#
# Epoch 25: val_loss did not improve from 0.00079
# 119/119 - 28s - 233ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 26/80
#
# Epoch 26: val_loss improved from 0.00079 to 0.00075, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 14s - 116ms/step - loss: 0.0012 - val_loss: 7.5060e-04
# Epoch 27/80
#
# Epoch 27: val_loss did not improve from 0.00075
# 119/119 - 18s - 153ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 28/80
#
# Epoch 28: val_loss did not improve from 0.00075
# 119/119 - 12s - 101ms/step - loss: 0.0012 - val_loss: 9.0654e-04
# Epoch 29/80
#
# Epoch 29: val_loss improved from 0.00075 to 0.00073, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 21s - 173ms/step - loss: 0.0011 - val_loss: 7.2618e-04
# Epoch 30/80
#
# Epoch 30: val_loss did not improve from 0.00073
# 119/119 - 9s - 73ms/step - loss: 0.0013 - val_loss: 9.0584e-04
# Epoch 31/80
#
# Epoch 31: val_loss improved from 0.00073 to 0.00071, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 92ms/step - loss: 0.0011 - val_loss: 7.0818e-04
# Epoch 32/80
#
# Epoch 32: val_loss did not improve from 0.00071
# 119/119 - 12s - 98ms/step - loss: 0.0011 - val_loss: 7.3180e-04
# Epoch 33/80
#
# Epoch 33: val_loss improved from 0.00071 to 0.00068, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 94ms/step - loss: 0.0011 - val_loss: 6.7891e-04
# Epoch 34/80
#
# Epoch 34: val_loss did not improve from 0.00068
# 119/119 - 19s - 158ms/step - loss: 0.0011 - val_loss: 6.9587e-04
# Epoch 35/80
#
# Epoch 35: val_loss did not improve from 0.00068
# 119/119 - 12s - 97ms/step - loss: 0.0011 - val_loss: 7.7716e-04
# Epoch 36/80
#
# Epoch 36: val_loss improved from 0.00068 to 0.00064, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 19s - 160ms/step - loss: 0.0011 - val_loss: 6.4451e-04
# Epoch 37/80
#
# Epoch 37: val_loss did not improve from 0.00064
# 119/119 - 10s - 82ms/step - loss: 9.7262e-04 - val_loss: 6.9034e-04
# Epoch 38/80
#
# Epoch 38: val_loss did not improve from 0.00064
# 119/119 - 12s - 99ms/step - loss: 0.0010 - val_loss: 6.9898e-04
# Epoch 39/80
#
# Epoch 39: val_loss did not improve from 0.00064
# 119/119 - 21s - 175ms/step - loss: 0.0010 - val_loss: 6.8328e-04
# Epoch 40/80
#
# Epoch 40: val_loss did not improve from 0.00064
# 119/119 - 20s - 172ms/step - loss: 0.0010 - val_loss: 7.1971e-04
# Epoch 41/80
#
# Epoch 41: val_loss did not improve from 0.00064
# 119/119 - 20s - 172ms/step - loss: 9.6480e-04 - val_loss: 6.7935e-04
# Epoch 42/80
#
# Epoch 42: val_loss improved from 0.00064 to 0.00060, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 9s - 77ms/step - loss: 9.0179e-04 - val_loss: 5.9955e-04
# Epoch 43/80
#
# Epoch 43: val_loss did not improve from 0.00060
# 119/119 - 12s - 97ms/step - loss: 9.2225e-04 - val_loss: 7.3899e-04
# Epoch 44/80
#
# Epoch 44: val_loss did not improve from 0.00060
# 119/119 - 21s - 178ms/step - loss: 8.9593e-04 - val_loss: 6.9862e-04
# Epoch 45/80
#
# Epoch 45: val_loss improved from 0.00060 to 0.00059, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 10s - 86ms/step - loss: 8.8981e-04 - val_loss: 5.9219e-04
# Epoch 46/80
#
# Epoch 46: val_loss improved from 0.00059 to 0.00057, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 10s - 85ms/step - loss: 8.8845e-04 - val_loss: 5.7139e-04
# Epoch 47/80
#
# Epoch 47: val_loss did not improve from 0.00057
# 119/119 - 11s - 94ms/step - loss: 8.7559e-04 - val_loss: 7.9930e-04
# Epoch 48/80
#
# Epoch 48: val_loss did not improve from 0.00057
# 119/119 - 11s - 94ms/step - loss: 8.7569e-04 - val_loss: 6.5227e-04
# Epoch 49/80
#
# Epoch 49: val_loss did not improve from 0.00057
# 119/119 - 19s - 160ms/step - loss: 8.8636e-04 - val_loss: 5.7605e-04
# Epoch 50/80
#
# Epoch 50: val_loss did not improve from 0.00057
# 119/119 - 11s - 94ms/step - loss: 9.1467e-04 - val_loss: 6.4611e-04
# Epoch 51/80
#
# Epoch 51: val_loss improved from 0.00057 to 0.00054, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 19s - 163ms/step - loss: 8.5051e-04 - val_loss: 5.3557e-04
# Epoch 52/80
#
# Epoch 52: val_loss did not improve from 0.00054
# 119/119 - 10s - 85ms/step - loss: 8.4919e-04 - val_loss: 5.9931e-04
# Epoch 53/80
#
# Epoch 53: val_loss did not improve from 0.00054
# 119/119 - 11s - 94ms/step - loss: 8.5336e-04 - val_loss: 5.6695e-04
# Epoch 54/80
#
# Epoch 54: val_loss did not improve from 0.00054
# 119/119 - 20s - 165ms/step - loss: 9.0733e-04 - val_loss: 6.6349e-04
# Epoch 55/80
#
# Epoch 55: val_loss did not improve from 0.00054
# 119/119 - 21s - 179ms/step - loss: 8.2906e-04 - val_loss: 5.6694e-04
# Epoch 56/80
#
# Epoch 56: val_loss improved from 0.00054 to 0.00050, saving model to /content/drive/MyDrive/2025/revenue_model.keras
# 119/119 - 11s - 93ms/step - loss: 8.1872e-04 - val_loss: 4.9985e-04
# Epoch 57/80
#
# Epoch 57: val_loss did not improve from 0.00050
# 119/119 - 10s - 88ms/step - loss: 7.9303e-04 - val_loss: 6.1534e-04
# Epoch 58/80
#
# Epoch 58: val_loss did not improve from 0.00050
# 119/119 - 21s - 176ms/step - loss: 8.6672e-04 - val_loss: 6.1127e-04
# Epoch 59/80
#
# Epoch 59: val_loss did not improve from 0.00050
# 119/119 - 21s - 176ms/step - loss: 8.2999e-04 - val_loss: 6.0470e-04
# Epoch 60/80
#
# Epoch 60: val_loss did not improve from 0.00050
# 119/119 - 20s - 170ms/step - loss: 8.3046e-04 - val_loss: 0.0010
# Epoch 61/80
#
# Epoch 61: val_loss did not improve from 0.00050
# 119/119 - 21s - 174ms/step - loss: 8.6499e-04 - val_loss: 5.0622e-04
# Epoch 62/80
#
# Epoch 62: val_loss did not improve from 0.00050
# 119/119 - 20s - 169ms/step - loss: 8.0422e-04 - val_loss: 5.6367e-04
# Epoch 63/80
#
# Epoch 63: val_loss did not improve from 0.00050
# 119/119 - 20s - 171ms/step - loss: 7.5904e-04 - val_loss: 5.7169e-04
# Epoch 64/80
#
# Epoch 64: val_loss did not improve from 0.00050
# 119/119 - 21s - 175ms/step - loss: 8.1825e-04 - val_loss: 5.9228e-04
# Epoch 65/80
#
# Epoch 65: val_loss did not improve from 0.00050
# 119/119 - 20s - 169ms/step - loss: 8.0124e-04 - val_loss: 6.1849e-04
# Epoch 66/80
#
# Epoch 66: val_loss did not improve from 0.00050
# 119/119 - 20s - 169ms/step - loss: 7.6403e-04 - val_loss: 5.4352e-04
# Epoch 67/80
#
# Epoch 67: val_loss did not improve from 0.00050
# 119/119 - 20s - 172ms/step - loss: 7.6160e-04 - val_loss: 7.4627e-04
# Epoch 68/80
#
# Epoch 68: val_loss did not improve from 0.00050
# 119/119 - 9s - 75ms/step - loss: 7.6611e-04 - val_loss: 6.1536e-04
# Epoch 69/80
#
# Epoch 69: val_loss did not improve from 0.00050
# 119/119 - 12s - 99ms/step - loss: 7.9880e-04 - val_loss: 6.6622e-04
# Epoch 70/80
#
# Epoch 70: val_loss did not improve from 0.00050
# 119/119 - 21s - 175ms/step - loss: 7.5079e-04 - val_loss: 5.7030e-04
# Epoch 71/80
#
# Epoch 71: val_loss did not improve from 0.00050
# 119/119 - 20s - 165ms/step - loss: 7.5021e-04 - val_loss: 6.1647e-04
# Epoch 72/80
#
# Epoch 72: val_loss did not improve from 0.00050
# 119/119 - 11s - 91ms/step - loss: 7.1804e-04 - val_loss: 5.5420e-04
# Epoch 73/80
#
# Epoch 73: val_loss did not improve from 0.00050
# 119/119 - 11s - 92ms/step - loss: 7.6636e-04 - val_loss: 5.6347e-04
# Epoch 74/80
#
# Epoch 74: val_loss did not improve from 0.00050
# 119/119 - 20s - 170ms/step - loss: 7.7871e-04 - val_loss: 5.7895e-04
# Epoch 75/80
#
# Epoch 75: val_loss did not improve from 0.00050
# 119/119 - 11s - 91ms/step - loss: 8.2743e-04 - val_loss: 6.1126e-04
# Epoch 76/80
#
# Epoch 76: val_loss did not improve from 0.00050
# 119/119 - 19s - 156ms/step - loss: 7.1581e-04 - val_loss: 5.3602e-04
# Epoch 77/80
#
# Epoch 77: val_loss did not improve from 0.00050
# 119/119 - 11s - 95ms/step - loss: 7.6018e-04 - val_loss: 6.2331e-04
# Epoch 78/80
#
# Epoch 78: val_loss did not improve from 0.00050
# 119/119 - 11s - 95ms/step - loss: 7.4025e-04 - val_loss: 5.2783e-04
# Epoch 79/80
#
# Epoch 79: val_loss did not improve from 0.00050
# 119/119 - 19s - 163ms/step - loss: 7.0308e-04 - val_loss: 7.2441e-04
# Epoch 80/80
#
# Epoch 80: val_loss did not improve from 0.00050
# 119/119 - 10s - 84ms/step - loss: 7.4465e-04 - val_loss: 5.7389e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step

# %%
# Dự đoán trên tập train
y_train_pred = model.predict(X_train)
y_train_pred_inv = scaler.inverse_transform(np.concatenate((y_train_pred, np.zeros((y_train_pred.shape[0], 3))), axis=1))[:, 0]
y_train_inv = scaler.inverse_transform(np.concatenate((y_train.reshape(-1, 1), np.zeros((y_train.shape[0], 3))), axis=1))[:, 0]
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step

# %%
#r2
print('R^2:',r2_score(y_train_inv,y_train_pred_inv))
#RMSE
print('RMSE tập train:',np.sqrt(mean_squared_error(y_train_inv,y_train_pred_inv)))
#mape
print('MAPE tập train:',mean_absolute_percentage_error(y_train_inv,y_train_pred_inv))
# Out:
# R^2: 0.9666258014606631
# RMSE tập train: 144861.90984665582
# MAPE tập train: 0.06101216189657851

# %%
#r2
print('R^2:',r2_score(y_test_actual,predictions))
#RMSE
print('RMSE tập test:',np.sqrt(mean_squared_error(y_test_actual,predictions)))
#mae
print('MAPE tập test:',mean_absolute_percentage_error(y_test_actual,predictions))
# Out:
# R^2: 0.9455092772638767
# RMSE tập test: 124520.59705162894
# MAPE tập test: 0.0652135981524038

# %%
# Vẽ biểu đồ so sánh kết quả
plt.figure(figsize=(10,6))
plt.plot(y_test_actual, color='blue', label='Doanh thu thật')
plt.plot(predictions, color='red', label='Dự đoán doanh thu')
plt.title('So sánh Doanh thu thật và Dự đoán')
plt.xlabel('Ngày')
plt.ylabel('Doanh thu')
plt.legend()
plt.show()

# %% [markdown]
# ## II. Unit Sold

# %%
# Chuẩn hóa dữ liệu (Scaling từ 0 đến 1)
scaler = MinMaxScaler(feature_range=(0, 1))
sc_train = scaler.fit_transform(train_units[['unit_MA_7','unit_MA_15','unit_MA_30','unit_MA_60']])
sc_test = scaler.transform(test_units[['unit_MA_7','unit_MA_15','unit_MA_30','unit_MA_60']])

# %%
# Chuyển đổi dữ liệu thành dạng có thể sử dụng cho LSTM (sequence data)
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), :])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Tạo dữ liệu đầu vào cho mô hình LSTM
time_step = 45  # Sử dụng 45 ngày trước đó để dự đoán ngày tiếp theo
X_train, y_train = create_dataset(sc_train, time_step)
X_test, y_test = create_dataset(sc_test, time_step)

# Reshape dữ liệu cho LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],  X_test.shape[2])

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Sử dụng ModelCheckpoint để lưu mô hình tốt nhất
save_model = "/content/drive/MyDrive/2025/unit_model.keras"
best_model = ModelCheckpoint(save_model, monitor='val_loss', verbose=2, save_best_only=True, mode='auto')
model.fit(X_train, y_train, epochs=80, batch_size=32, verbose=2, validation_data=(X_test, y_test), callbacks=[best_model])

# Dự đoán doanh thu cho tập test
predictions = model.predict(X_test)

# Chuyển đổi dự đoán trở lại giá trị gốc (denormalization)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], 3))), axis=1))[:, 0]
y_test_actual = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 3))), axis=1))[:, 0]
# Out:
# Epoch 1/80
#
# Epoch 1: val_loss improved from inf to 0.00243, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 15s - 126ms/step - loss: 0.0130 - val_loss: 0.0024
# Epoch 2/80
#
# Epoch 2: val_loss improved from 0.00243 to 0.00114, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 19s - 161ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 3/80
#
# Epoch 3: val_loss improved from 0.00114 to 0.00089, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 178ms/step - loss: 0.0032 - val_loss: 8.9176e-04
# Epoch 4/80
#
# Epoch 4: val_loss improved from 0.00089 to 0.00088, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 19s - 156ms/step - loss: 0.0027 - val_loss: 8.7676e-04
# Epoch 5/80
#
# Epoch 5: val_loss improved from 0.00088 to 0.00077, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 12s - 102ms/step - loss: 0.0025 - val_loss: 7.7062e-04
# Epoch 6/80
#
# Epoch 6: val_loss did not improve from 0.00077
# 119/119 - 20s - 169ms/step - loss: 0.0023 - val_loss: 8.7923e-04
# Epoch 7/80
#
# Epoch 7: val_loss improved from 0.00077 to 0.00069, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 175ms/step - loss: 0.0022 - val_loss: 6.9185e-04
# Epoch 8/80
#
# Epoch 8: val_loss improved from 0.00069 to 0.00053, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 172ms/step - loss: 0.0020 - val_loss: 5.3178e-04
# Epoch 9/80
#
# Epoch 9: val_loss did not improve from 0.00053
# 119/119 - 20s - 169ms/step - loss: 0.0019 - val_loss: 5.9345e-04
# Epoch 10/80
#
# Epoch 10: val_loss improved from 0.00053 to 0.00053, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 174ms/step - loss: 0.0019 - val_loss: 5.3032e-04
# Epoch 11/80
#
# Epoch 11: val_loss improved from 0.00053 to 0.00053, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 9s - 77ms/step - loss: 0.0018 - val_loss: 5.2797e-04
# Epoch 12/80
#
# Epoch 12: val_loss improved from 0.00053 to 0.00048, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 94ms/step - loss: 0.0017 - val_loss: 4.7976e-04
# Epoch 13/80
#
# Epoch 13: val_loss improved from 0.00048 to 0.00044, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 94ms/step - loss: 0.0017 - val_loss: 4.3525e-04
# Epoch 14/80
#
# Epoch 14: val_loss did not improve from 0.00044
# 119/119 - 19s - 160ms/step - loss: 0.0016 - val_loss: 4.6959e-04
# Epoch 15/80
#
# Epoch 15: val_loss did not improve from 0.00044
# 119/119 - 10s - 84ms/step - loss: 0.0016 - val_loss: 5.0174e-04
# Epoch 16/80
#
# Epoch 16: val_loss improved from 0.00044 to 0.00042, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 95ms/step - loss: 0.0016 - val_loss: 4.2378e-04
# Epoch 17/80
#
# Epoch 17: val_loss did not improve from 0.00042
# 119/119 - 19s - 162ms/step - loss: 0.0016 - val_loss: 4.9266e-04
# Epoch 18/80
#
# Epoch 18: val_loss did not improve from 0.00042
# 119/119 - 10s - 81ms/step - loss: 0.0015 - val_loss: 4.2643e-04
# Epoch 19/80
#
# Epoch 19: val_loss improved from 0.00042 to 0.00040, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 91ms/step - loss: 0.0015 - val_loss: 3.9718e-04
# Epoch 20/80
#
# Epoch 20: val_loss did not improve from 0.00040
# 119/119 - 11s - 92ms/step - loss: 0.0016 - val_loss: 4.3378e-04
# Epoch 21/80
#
# Epoch 21: val_loss improved from 0.00040 to 0.00039, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 167ms/step - loss: 0.0014 - val_loss: 3.8561e-04
# Epoch 22/80
#
# Epoch 22: val_loss improved from 0.00039 to 0.00038, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 93ms/step - loss: 0.0015 - val_loss: 3.8256e-04
# Epoch 23/80
#
# Epoch 23: val_loss did not improve from 0.00038
# 119/119 - 19s - 163ms/step - loss: 0.0014 - val_loss: 4.0606e-04
# Epoch 24/80
#
# Epoch 24: val_loss did not improve from 0.00038
# 119/119 - 10s - 85ms/step - loss: 0.0014 - val_loss: 4.8236e-04
# Epoch 25/80
#
# Epoch 25: val_loss improved from 0.00038 to 0.00037, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 11s - 95ms/step - loss: 0.0014 - val_loss: 3.7287e-04
# Epoch 26/80
#
# Epoch 26: val_loss did not improve from 0.00037
# 119/119 - 20s - 168ms/step - loss: 0.0014 - val_loss: 4.6043e-04
# Epoch 27/80
#
# Epoch 27: val_loss did not improve from 0.00037
# 119/119 - 21s - 174ms/step - loss: 0.0014 - val_loss: 3.7799e-04
# Epoch 28/80
#
# Epoch 28: val_loss improved from 0.00037 to 0.00037, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 179ms/step - loss: 0.0014 - val_loss: 3.6680e-04
# Epoch 29/80
#
# Epoch 29: val_loss improved from 0.00037 to 0.00037, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 165ms/step - loss: 0.0014 - val_loss: 3.6575e-04
# Epoch 30/80
#
# Epoch 30: val_loss improved from 0.00037 to 0.00036, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 172ms/step - loss: 0.0013 - val_loss: 3.6404e-04
# Epoch 31/80
#
# Epoch 31: val_loss did not improve from 0.00036
# 119/119 - 21s - 173ms/step - loss: 0.0013 - val_loss: 3.8306e-04
# Epoch 32/80
#
# Epoch 32: val_loss did not improve from 0.00036
# 119/119 - 21s - 173ms/step - loss: 0.0014 - val_loss: 5.3577e-04
# Epoch 33/80
#
# Epoch 33: val_loss did not improve from 0.00036
# 119/119 - 20s - 169ms/step - loss: 0.0013 - val_loss: 4.3231e-04
# Epoch 34/80
#
# Epoch 34: val_loss did not improve from 0.00036
# 119/119 - 21s - 172ms/step - loss: 0.0013 - val_loss: 4.2100e-04
# Epoch 35/80
#
# Epoch 35: val_loss did not improve from 0.00036
# 119/119 - 20s - 166ms/step - loss: 0.0012 - val_loss: 4.6085e-04
# Epoch 36/80
#
# Epoch 36: val_loss did not improve from 0.00036
# 119/119 - 11s - 91ms/step - loss: 0.0013 - val_loss: 3.7248e-04
# Epoch 37/80
#
# Epoch 37: val_loss improved from 0.00036 to 0.00033, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 165ms/step - loss: 0.0012 - val_loss: 3.3248e-04
# Epoch 38/80
#
# Epoch 38: val_loss did not improve from 0.00033
# 119/119 - 10s - 84ms/step - loss: 0.0012 - val_loss: 3.7784e-04
# Epoch 39/80
#
# Epoch 39: val_loss did not improve from 0.00033
# 119/119 - 11s - 95ms/step - loss: 0.0012 - val_loss: 4.8448e-04
# Epoch 40/80
#
# Epoch 40: val_loss did not improve from 0.00033
# 119/119 - 20s - 171ms/step - loss: 0.0012 - val_loss: 3.4800e-04
# Epoch 41/80
#
# Epoch 41: val_loss did not improve from 0.00033
# 119/119 - 21s - 175ms/step - loss: 0.0012 - val_loss: 4.5989e-04
# Epoch 42/80
#
# Epoch 42: val_loss did not improve from 0.00033
# 119/119 - 20s - 171ms/step - loss: 0.0012 - val_loss: 5.0130e-04
# Epoch 43/80
#
# Epoch 43: val_loss did not improve from 0.00033
# 119/119 - 20s - 172ms/step - loss: 0.0012 - val_loss: 4.5428e-04
# Epoch 44/80
#
# Epoch 44: val_loss did not improve from 0.00033
# 119/119 - 21s - 173ms/step - loss: 0.0011 - val_loss: 4.1659e-04
# Epoch 45/80
#
# Epoch 45: val_loss did not improve from 0.00033
# 119/119 - 9s - 73ms/step - loss: 0.0011 - val_loss: 5.2181e-04
# Epoch 46/80
#
# Epoch 46: val_loss did not improve from 0.00033
# 119/119 - 11s - 91ms/step - loss: 0.0012 - val_loss: 3.3947e-04
# Epoch 47/80
#
# Epoch 47: val_loss did not improve from 0.00033
# 119/119 - 20s - 171ms/step - loss: 0.0012 - val_loss: 3.8057e-04
# Epoch 48/80
#
# Epoch 48: val_loss did not improve from 0.00033
# 119/119 - 9s - 73ms/step - loss: 0.0011 - val_loss: 3.4701e-04
# Epoch 49/80
#
# Epoch 49: val_loss improved from 0.00033 to 0.00031, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 12s - 99ms/step - loss: 0.0011 - val_loss: 3.0558e-04
# Epoch 50/80
#
# Epoch 50: val_loss did not improve from 0.00031
# 119/119 - 21s - 178ms/step - loss: 0.0011 - val_loss: 3.9387e-04
# Epoch 51/80
#
# Epoch 51: val_loss did not improve from 0.00031
# 119/119 - 19s - 163ms/step - loss: 0.0012 - val_loss: 3.1281e-04
# Epoch 52/80
#
# Epoch 52: val_loss did not improve from 0.00031
# 119/119 - 11s - 95ms/step - loss: 0.0011 - val_loss: 3.1194e-04
# Epoch 53/80
#
# Epoch 53: val_loss did not improve from 0.00031
# 119/119 - 20s - 166ms/step - loss: 0.0010 - val_loss: 3.8726e-04
# Epoch 54/80
#
# Epoch 54: val_loss did not improve from 0.00031
# 119/119 - 9s - 78ms/step - loss: 0.0010 - val_loss: 3.1719e-04
# Epoch 55/80
#
# Epoch 55: val_loss did not improve from 0.00031
# 119/119 - 12s - 100ms/step - loss: 0.0010 - val_loss: 3.2888e-04
# Epoch 56/80
#
# Epoch 56: val_loss improved from 0.00031 to 0.00029, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 170ms/step - loss: 9.9390e-04 - val_loss: 2.9446e-04
# Epoch 57/80
#
# Epoch 57: val_loss did not improve from 0.00029
# 119/119 - 9s - 74ms/step - loss: 0.0011 - val_loss: 3.4962e-04
# Epoch 58/80
#
# Epoch 58: val_loss did not improve from 0.00029
# 119/119 - 12s - 101ms/step - loss: 9.8558e-04 - val_loss: 3.7185e-04
# Epoch 59/80
#
# Epoch 59: val_loss did not improve from 0.00029
# 119/119 - 21s - 173ms/step - loss: 9.8857e-04 - val_loss: 3.1522e-04
# Epoch 60/80
#
# Epoch 60: val_loss did not improve from 0.00029
# 119/119 - 20s - 167ms/step - loss: 0.0011 - val_loss: 3.3162e-04
# Epoch 61/80
#
# Epoch 61: val_loss did not improve from 0.00029
# 119/119 - 11s - 92ms/step - loss: 9.5285e-04 - val_loss: 3.5026e-04
# Epoch 62/80
#
# Epoch 62: val_loss did not improve from 0.00029
# 119/119 - 18s - 155ms/step - loss: 0.0010 - val_loss: 3.0656e-04
# Epoch 63/80
#
# Epoch 63: val_loss did not improve from 0.00029
# 119/119 - 11s - 92ms/step - loss: 9.2007e-04 - val_loss: 3.7786e-04
# Epoch 64/80
#
# Epoch 64: val_loss did not improve from 0.00029
# 119/119 - 11s - 95ms/step - loss: 8.9544e-04 - val_loss: 3.0754e-04
# Epoch 65/80
#
# Epoch 65: val_loss did not improve from 0.00029
# 119/119 - 11s - 93ms/step - loss: 0.0010 - val_loss: 4.3728e-04
# Epoch 66/80
#
# Epoch 66: val_loss did not improve from 0.00029
# 119/119 - 10s - 84ms/step - loss: 9.4654e-04 - val_loss: 3.2157e-04
# Epoch 67/80
#
# Epoch 67: val_loss did not improve from 0.00029
# 119/119 - 10s - 82ms/step - loss: 9.8736e-04 - val_loss: 3.5062e-04
# Epoch 68/80
#
# Epoch 68: val_loss did not improve from 0.00029
# 119/119 - 12s - 97ms/step - loss: 9.1163e-04 - val_loss: 3.2501e-04
# Epoch 69/80
#
# Epoch 69: val_loss did not improve from 0.00029
# 119/119 - 21s - 177ms/step - loss: 9.4383e-04 - val_loss: 3.1022e-04
# Epoch 70/80
#
# Epoch 70: val_loss did not improve from 0.00029
# 119/119 - 9s - 77ms/step - loss: 9.2971e-04 - val_loss: 3.0361e-04
# Epoch 71/80
#
# Epoch 71: val_loss did not improve from 0.00029
# 119/119 - 12s - 100ms/step - loss: 8.9369e-04 - val_loss: 3.9854e-04
# Epoch 72/80
#
# Epoch 72: val_loss did not improve from 0.00029
# 119/119 - 11s - 94ms/step - loss: 9.2429e-04 - val_loss: 3.3741e-04
# Epoch 73/80
#
# Epoch 73: val_loss improved from 0.00029 to 0.00027, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 21s - 175ms/step - loss: 8.4909e-04 - val_loss: 2.7449e-04
# Epoch 74/80
#
# Epoch 74: val_loss did not improve from 0.00027
# 119/119 - 21s - 175ms/step - loss: 8.7755e-04 - val_loss: 3.5344e-04
# Epoch 75/80
#
# Epoch 75: val_loss did not improve from 0.00027
# 119/119 - 20s - 166ms/step - loss: 8.4371e-04 - val_loss: 3.3527e-04
# Epoch 76/80
#
# Epoch 76: val_loss did not improve from 0.00027
# 119/119 - 21s - 173ms/step - loss: 8.6605e-04 - val_loss: 2.8997e-04
# Epoch 77/80
#
# Epoch 77: val_loss did not improve from 0.00027
# 119/119 - 20s - 167ms/step - loss: 8.1091e-04 - val_loss: 2.9934e-04
# Epoch 78/80
#
# Epoch 78: val_loss did not improve from 0.00027
# 119/119 - 21s - 178ms/step - loss: 8.3505e-04 - val_loss: 2.8369e-04
# Epoch 79/80
#
# Epoch 79: val_loss improved from 0.00027 to 0.00026, saving model to /content/drive/MyDrive/2025/unit_model.keras
# 119/119 - 20s - 172ms/step - loss: 8.6111e-04 - val_loss: 2.6488e-04
# Epoch 80/80
#
# Epoch 80: val_loss did not improve from 0.00026
# 119/119 - 9s - 80ms/step - loss: 8.2340e-04 - val_loss: 2.6815e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step

# %%
# Dự đoán trên tập train
y_train_pred = model.predict(X_train)
y_train_pred_inv = scaler.inverse_transform(np.concatenate((y_train_pred, np.zeros((y_train_pred.shape[0], 3))), axis=1))[:, 0]
y_train_inv = scaler.inverse_transform(np.concatenate((y_train.reshape(-1, 1), np.zeros((y_train.shape[0], 3))), axis=1))[:, 0]
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step

# %%
#r2
print('R^2:',r2_score(y_train_inv,y_train_pred_inv))
#RMSE
print('RMSE tập train:',np.sqrt(mean_squared_error(y_train_inv,y_train_pred_inv)))
#mape
print('MAPE tập train:',mean_absolute_percentage_error(y_train_inv,y_train_pred_inv))
# Out:
# R^2: 0.9733043583483563
# RMSE tập train: 26.93127194542798
# MAPE tập train: 0.06328105338247235

# %%
#r2
print('R^2:',r2_score(y_test_actual,predictions))
#RMSE
print('RMSE tập test:',np.sqrt(mean_squared_error(y_test_actual,predictions)))
#mae
print('MAPE tập test:',mean_absolute_percentage_error(y_test_actual,predictions))
# Out:
# R^2: 0.9425116002950898
# RMSE tập test: 15.921575959129283
# MAPE tập test: 0.0677541154878385

# %%
# Vẽ biểu đồ so sánh kết quả
plt.figure(figsize=(10,6))
plt.plot(y_test_actual, color='blue', label='Doanh thu thật')
plt.plot(predictions, color='red', label='Dự đoán doanh thu')
plt.title('So sánh số lượng bán thật và Dự đoán')
plt.xlabel('Ngày')
plt.ylabel('Doanh thu')
plt.legend()
plt.show()
